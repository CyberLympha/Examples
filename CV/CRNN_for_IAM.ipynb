# %%
import os
import math
import string

import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.backend import get_value, ctc_decode
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Nadam

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Prepare dataset

# %%
# !mkdir lines
# https://fki.tic.heia-fr.ch/DBs/iamDB/data/lines.tgz
# !tar -xf path/to/lines.tgz -C ./lines
# https://fki.tic.heia-fr.ch/DBs/iamDB/data/ascii.tgz
# !tar -xf path/to/ascii.tar -C ./

# %%
# Load labels

gt = pd.DataFrame(columns=['fn', 'value'])

with open('./lines.txt', 'r') as f:
  for index, row in enumerate(f):
    if row[0] == '#':
      continue
    row = row.split()
    gt.loc[gt.shape[0]] = (row[0], row[-1].replace('|', ' '))
gt.head(5)
# Out:
#             fn                                  value
# 0  a01-000u-00      A MOVE to stop Mr. Gaitskell from
# 1  a01-000u-01  nominating any more Labour life Peers
# 2  a01-000u-02   is to be made at a meeting of Labour
# 3  a01-000u-03     Ps tomorrow . Mr. Michael Foot has
# 4  a01-000u-04   put down a resolution on the subject

# %%
# Data preprocessing

def preprocess(img):
  for func in [resize_n_rotate, add_adaptiveThreshold]:
    img = func(img)
  return img


def resize_n_rotate(img, shape_to=(64, 800)):
  if img.shape[0] > shape_to[0] or img.shape[1] > shape_to[1]:
    shrink_multiplayer = min(math.floor(shape_to[0] / img.shape[0] * 100) / 100,
                             math.floor(shape_to[1] / img.shape[1] * 100) / 100)
    img = cv2.resize(img, None, 
                     fx=shrink_multiplayer, 
                     fy=shrink_multiplayer, 
                     interpolation=cv2.INTER_AREA)
    
  img = cv2.copyMakeBorder(img, math.ceil(shape_to[0]/2) - math.ceil(img.shape[0]/2), 
                           math.floor(shape_to[0]/2) - math.floor(img.shape[0]/2), 
                           math.ceil(shape_to[1]/2) - math.ceil(img.shape[1]/2), 
                           math.floor(shape_to[1]/2) - math.floor(img.shape[1]/2), 
                           cv2.BORDER_CONSTANT, value=255)
  return cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)


def add_adaptiveThreshold(img):
  return cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 21, 10).astype('bool')


# Label encoding

def encode_text(texts):
  def _label_to_num(label, alphabet):
    label_num = []
    for ch in label:
      label_num.append(alphabet.find(ch))
    return np.array(label_num)
  
  alphabet = ''.join(sorted(pd.Series(texts).apply(list).apply(pd.Series).stack().unique()))
  
  nums = np.ones([len(texts), max([len(text) for text in texts])], dtype='int64') * len(alphabet)
  for i, text in enumerate(texts):
    nums[i][:len(text)] = _label_to_num(text, alphabet)
  
  return nums, alphabet

# %%
# Load and preprocess data

train_X, train_y = [], []

for sub_folder1 in tqdm(os.listdir('./lines')):
  for sub_folder2 in os.listdir(f'./lines/{sub_folder1}'):
    for sub_folder3 in os.listdir(f'./lines/{sub_folder1}/{sub_folder2}'):
      
      label = gt[gt.fn == sub_folder3[:sub_folder3.rfind('.')]].value.tolist()[0]
      if not any(list(map(lambda e: e not in string.ascii_letters + ',.\' ', label))):
        train_X.append(preprocess(cv2.imread(f'./lines/{sub_folder1}/{sub_folder2}/{sub_folder3}', 0)))
        train_y.append(gt[gt.fn == sub_folder3[:sub_folder3.rfind('.')]].value.tolist()[0])

train_X = np.array(train_X)
train_y, alphabet = encode_text(train_y)
alphabet
# Out:
# 100%|██████████| 76/76 [00:55<00:00,  1.37it/s]
# " ',.ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"

# %%
train_X, val_X, train_y, val_y  = train_test_split(train_X, train_y, test_size=0.2, random_state=42)
train_X, test_X, train_y, test_y  = train_test_split(train_X, train_y, test_size=0.25, random_state=42)

# %%
fig, axes = plt.subplots(figsize=(20, 15), ncols=2, nrows=10)

# Preprocess example

for i in range(10):
  for j in range(2):
    axes[i, j % 2].imshow(cv2.rotate(
        (train_X[i * 2 + j % 2]).astype(np.uint8),cv2.ROTATE_90_COUNTERCLOCKWISE),
        cmap='gray')

# %% [markdown]
# # Model

# %%
class CERMetric(tf.keras.metrics.Metric):
    """
    A custom Keras metric to compute the Character Error Rate
    """
    def __init__(self, name='CER_metric', **kwargs):
        super(CERMetric, self).__init__(name=name, **kwargs)
        self.cer_accumulator = self.add_weight(name="total_cer", initializer="zeros")
        self.counter = self.add_weight(name="cer_count", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        input_shape = K.shape(y_pred)
        input_length = tf.ones(shape=input_shape[0]) * K.cast(input_shape[1], 'float32')

        decode, log = K.ctc_decode(y_pred, input_length, greedy=True)

        decode = K.ctc_label_dense_to_sparse(decode[0], K.cast(input_length, 'int32'))
        y_true_sparse = K.ctc_label_dense_to_sparse(y_true, K.cast(input_length, 'int32'))
        y_true_sparse = tf.sparse.retain(y_true_sparse, tf.not_equal(y_true_sparse.values, tf.math.reduce_max(y_true_sparse.values)))

        decode = tf.sparse.retain(decode, tf.not_equal(decode.values, -1))
        distance = tf.edit_distance(decode, y_true_sparse, normalize=True)

        self.cer_accumulator.assign_add(tf.reduce_sum(distance))
        self.counter.assign_add(K.cast(len(y_true), 'float32'))

    def result(self):
        return tf.math.divide_no_nan(self.cer_accumulator, self.counter)

    def reset_state(self):
        self.cer_accumulator.assign(0.0)
        self.counter.assign(0.0)


def CTCLoss(y_true, y_pred):
    """
    Compute the training-time loss value
    """
    batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
    input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
    label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

    input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

    loss = K.ctc_batch_cost(y_true, y_pred, input_length, label_length)
    return loss

# %%
model = Sequential()

model.add(Conv2D(64, (5, 5), padding='same', activation=LeakyReLU(alpha=0.01), input_shape=(800, 64, 1)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (5, 5), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((1, 2)))

model.add(Conv2D(128, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))

model.add(Conv2D(256, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(512, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((1, 2)))
model.add(BatchNormalization())

model.add(Conv2D(512, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((1, 2)))

model.add(Reshape((100, 512)))

model.add(Bidirectional(LSTM(256, return_sequences=True)))
model.add(Bidirectional(LSTM(256, return_sequences=True)))

model.add(Dense(len(alphabet) + 1, activation='softmax')) # +1 for ctc blank

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 800, 64, 64)       1664
#
#  max_pooling2d (MaxPooling2D  (None, 400, 32, 64)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 400, 32, 128)      204928
#
#  max_pooling2d_1 (MaxPooling  (None, 400, 16, 128)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 400, 16, 128)      147584
#
#  max_pooling2d_2 (MaxPooling  (None, 200, 8, 128)      0
#  2D)
#
#  batch_normalization (BatchN  (None, 200, 8, 128)      512
#  ormalization)
#
#  conv2d_3 (Conv2D)           (None, 200, 8, 256)       295168
#
#  conv2d_4 (Conv2D)           (None, 200, 8, 256)       590080
#
#  max_pooling2d_3 (MaxPooling  (None, 100, 4, 256)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 100, 4, 512)       1180160
#
#  max_pooling2d_4 (MaxPooling  (None, 100, 2, 512)      0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 100, 2, 512)      2048
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 100, 2, 512)       2359808
#
#  max_pooling2d_5 (MaxPooling  (None, 100, 1, 512)      0
#  2D)
#
#  reshape (Reshape)           (None, 100, 512)          0
#
#  bidirectional (Bidirectiona  (None, 100, 512)         1574912
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 100, 512)         1574912
#  nal)
#
#  dense (Dense)               (None, 100, 57)           29241
#
# =================================================================
# Total params: 7,961,017
# Trainable params: 7,959,737
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
model.compile(optimizer=Nadam(learning_rate=0.001, clipnorm=1.0), loss=CTCLoss, metrics=[CERMetric()])

# %% [markdown]
# # Train model

# %%
history = model.fit(train_X, train_y, validation_data=(val_X, val_y),
                    epochs=75, batch_size=64,
                    callbacks=[EarlyStopping(patience=10, restore_best_weights=True, monitor='val_CER_metric'), 
                              ReduceLROnPlateau(factor=0.5, min_lr=1e-5, patience=4, monitor='val_CER_metric')], 
                    verbose=1)
# Out:
# Epoch 1/75
# 93/93 [==============================] - 90s 653ms/step - loss: 111.4494 - CER_metric: 0.7985 - val_loss: 219.7781 - val_CER_metric: 0.9998 - lr: 0.0010
# Epoch 2/75
# 93/93 [==============================] - 57s 617ms/step - loss: 47.4308 - CER_metric: 0.3322 - val_loss: 230.0004 - val_CER_metric: 0.9987 - lr: 0.0010
# Epoch 3/75
# 93/93 [==============================] - 58s 628ms/step - loss: 25.4214 - CER_metric: 0.1803 - val_loss: 181.9997 - val_CER_metric: 0.7932 - lr: 0.0010
# Epoch 4/75
# 93/93 [==============================] - 59s 633ms/step - loss: 18.1136 - CER_metric: 0.1322 - val_loss: 157.5523 - val_CER_metric: 0.7503 - lr: 0.0010
# Epoch 5/75
# 93/93 [==============================] - 59s 630ms/step - loss: 13.6792 - CER_metric: 0.1014 - val_loss: 47.3651 - val_CER_metric: 0.3604 - lr: 0.0010
# Epoch 6/75
# 93/93 [==============================] - 59s 638ms/step - loss: 10.3296 - CER_metric: 0.0804 - val_loss: 20.0383 - val_CER_metric: 0.1479 - lr: 0.0010
# Epoch 7/75
# 93/93 [==============================] - 57s 615ms/step - loss: 7.8650 - CER_metric: 0.0631 - val_loss: 19.8679 - val_CER_metric: 0.1376 - lr: 0.0010
# Epoch 8/75
# 93/93 [==============================] - 59s 632ms/step - loss: 5.8901 - CER_metric: 0.0473 - val_loss: 19.0768 - val_CER_metric: 0.1274 - lr: 0.0010
# Epoch 9/75
# 93/93 [==============================] - 57s 609ms/step - loss: 4.5095 - CER_metric: 0.0353 - val_loss: 20.4807 - val_CER_metric: 0.1407 - lr: 0.0010
# Epoch 10/75
# 93/93 [==============================] - 59s 637ms/step - loss: 3.5816 - CER_metric: 0.0292 - val_loss: 20.7892 - val_CER_metric: 0.1303 - lr: 0.0010
# Epoch 11/75
# 93/93 [==============================] - 59s 634ms/step - loss: 2.8323 - CER_metric: 0.0224 - val_loss: 21.7420 - val_CER_metric: 0.1293 - lr: 0.0010
# Epoch 12/75
# 93/93 [==============================] - 59s 632ms/step - loss: 2.4953 - CER_metric: 0.0197 - val_loss: 21.4104 - val_CER_metric: 0.1275 - lr: 0.0010
# Epoch 13/75
# 93/93 [==============================] - 59s 640ms/step - loss: 1.1708 - CER_metric: 0.0080 - val_loss: 21.0057 - val_CER_metric: 0.1161 - lr: 5.0000e-04
# Epoch 14/75
# 93/93 [==============================] - 59s 630ms/step - loss: 0.6173 - CER_metric: 0.0040 - val_loss: 22.4925 - val_CER_metric: 0.1183 - lr: 5.0000e-04
# Epoch 15/75
# 93/93 [==============================] - 59s 633ms/step - loss: 0.5013 - CER_metric: 0.0030 - val_loss: 22.6225 - val_CER_metric: 0.1147 - lr: 5.0000e-04
# Epoch 16/75
# 93/93 [==============================] - 59s 637ms/step - loss: 0.4258 - CER_metric: 0.0026 - val_loss: 23.0852 - val_CER_metric: 0.1137 - lr: 5.0000e-04
# Epoch 17/75
# 93/93 [==============================] - 57s 611ms/step - loss: 0.3842 - CER_metric: 0.0024 - val_loss: 24.2356 - val_CER_metric: 0.1175 - lr: 5.0000e-04
# Epoch 18/75
# 93/93 [==============================] - 59s 632ms/step - loss: 0.3431 - CER_metric: 0.0022 - val_loss: 24.2616 - val_CER_metric: 0.1170 - lr: 5.0000e-04
# Epoch 19/75
# 93/93 [==============================] - 60s 646ms/step - loss: 0.3185 - CER_metric: 0.0021 - val_loss: 24.4726 - val_CER_metric: 0.1165 - lr: 5.0000e-04
# Epoch 20/75
# 93/93 [==============================] - 59s 634ms/step - loss: 0.3167 - CER_metric: 0.0023 - val_loss: 25.2075 - val_CER_metric: 0.1168 - lr: 5.0000e-04
# Epoch 21/75
# 93/93 [==============================] - 60s 642ms/step - loss: 0.1507 - CER_metric: 7.8084e-04 - val_loss: 23.9726 - val_CER_metric: 0.1084 - lr: 2.5000e-04
# Epoch 22/75
# 93/93 [==============================] - 58s 618ms/step - loss: 0.0647 - CER_metric: 2.4317e-04 - val_loss: 24.1237 - val_CER_metric: 0.1074 - lr: 2.5000e-04
# Epoch 23/75
# 93/93 [==============================] - 59s 632ms/step - loss: 0.0315 - CER_metric: 8.6233e-05 - val_loss: 24.0490 - val_CER_metric: 0.1057 - lr: 2.5000e-04
# Epoch 24/75
# 93/93 [==============================] - 57s 612ms/step - loss: 0.0214 - CER_metric: 6.0217e-05 - val_loss: 24.1399 - val_CER_metric: 0.1054 - lr: 2.5000e-04
# Epoch 25/75
# 93/93 [==============================] - 59s 639ms/step - loss: 0.0171 - CER_metric: 6.1390e-05 - val_loss: 24.2611 - val_CER_metric: 0.1051 - lr: 2.5000e-04
# Epoch 26/75
# 93/93 [==============================] - 59s 633ms/step - loss: 0.0163 - CER_metric: 6.8993e-05 - val_loss: 24.5392 - val_CER_metric: 0.1047 - lr: 2.5000e-04
# Epoch 27/75
# 93/93 [==============================] - 59s 634ms/step - loss: 0.0150 - CER_metric: 8.3598e-05 - val_loss: 24.6158 - val_CER_metric: 0.1047 - lr: 2.5000e-04
# Epoch 28/75
# 93/93 [==============================] - 59s 638ms/step - loss: 0.0127 - CER_metric: 6.0944e-05 - val_loss: 24.6937 - val_CER_metric: 0.1048 - lr: 2.5000e-04
# Epoch 29/75
# 93/93 [==============================] - 57s 613ms/step - loss: 0.0116 - CER_metric: 4.7850e-05 - val_loss: 24.7940 - val_CER_metric: 0.1044 - lr: 2.5000e-04
# Epoch 30/75
# 93/93 [==============================] - 57s 616ms/step - loss: 0.0109 - CER_metric: 3.8264e-05 - val_loss: 24.9441 - val_CER_metric: 0.1046 - lr: 2.5000e-04
# Epoch 31/75
# 93/93 [==============================] - 57s 609ms/step - loss: 0.0113 - CER_metric: 3.8401e-05 - val_loss: 24.7951 - val_CER_metric: 0.1043 - lr: 2.5000e-04
# Epoch 32/75
# 93/93 [==============================] - 59s 639ms/step - loss: 0.0099 - CER_metric: 3.6452e-05 - val_loss: 25.0695 - val_CER_metric: 0.1045 - lr: 2.5000e-04
# Epoch 33/75
# 93/93 [==============================] - 59s 633ms/step - loss: 0.0095 - CER_metric: 2.9530e-05 - val_loss: 25.1461 - val_CER_metric: 0.1046 - lr: 2.5000e-04
# Epoch 34/75
# 93/93 [==============================] - 59s 636ms/step - loss: 0.0095 - CER_metric: 3.3552e-05 - val_loss: 25.1822 - val_CER_metric: 0.1045 - lr: 1.2500e-04
# Epoch 35/75
# 93/93 [==============================] - 57s 613ms/step - loss: 0.0086 - CER_metric: 4.3183e-05 - val_loss: 25.2847 - val_CER_metric: 0.1048 - lr: 1.2500e-04
# Epoch 36/75
# 93/93 [==============================] - 59s 632ms/step - loss: 0.0081 - CER_metric: 1.9345e-05 - val_loss: 25.2400 - val_CER_metric: 0.1042 - lr: 1.2500e-04
# Epoch 37/75
# 93/93 [==============================] - 56s 608ms/step - loss: 0.0078 - CER_metric: 1.9345e-05 - val_loss: 25.3477 - val_CER_metric: 0.1043 - lr: 1.2500e-04
# Epoch 38/75
# 93/93 [==============================] - 59s 638ms/step - loss: 0.0077 - CER_metric: 1.9345e-05 - val_loss: 25.3739 - val_CER_metric: 0.1043 - lr: 1.2500e-04
# Epoch 39/75
# 93/93 [==============================] - 59s 631ms/step - loss: 0.0077 - CER_metric: 9.5588e-06 - val_loss: 25.4214 - val_CER_metric: 0.1045 - lr: 1.2500e-04
# Epoch 40/75
# 93/93 [==============================] - 59s 633ms/step - loss: 0.0073 - CER_metric: 1.9345e-05 - val_loss: 25.5052 - val_CER_metric: 0.1044 - lr: 1.2500e-04
# Epoch 41/75
# 93/93 [==============================] - 57s 611ms/step - loss: 0.0072 - CER_metric: 1.6083e-05 - val_loss: 25.5311 - val_CER_metric: 0.1043 - lr: 6.2500e-05
# Epoch 42/75
# 93/93 [==============================] - 57s 613ms/step - loss: 0.0073 - CER_metric: 1.6355e-05 - val_loss: 25.5493 - val_CER_metric: 0.1046 - lr: 6.2500e-05
# Epoch 43/75
# 93/93 [==============================] - 59s 630ms/step - loss: 0.0077 - CER_metric: 1.9617e-05 - val_loss: 25.5358 - val_CER_metric: 0.1047 - lr: 6.2500e-05
# Epoch 44/75
# 93/93 [==============================] - 56s 606ms/step - loss: 0.0070 - CER_metric: 1.6083e-05 - val_loss: 25.5943 - val_CER_metric: 0.1045 - lr: 6.2500e-05
# Epoch 45/75
# 93/93 [==============================] - 56s 607ms/step - loss: 0.0068 - CER_metric: 1.6083e-05 - val_loss: 25.5991 - val_CER_metric: 0.1044 - lr: 3.1250e-05
# Epoch 46/75
# 93/93 [==============================] - 59s 636ms/step - loss: 0.0068 - CER_metric: 1.6083e-05 - val_loss: 25.6031 - val_CER_metric: 0.1043 - lr: 3.1250e-05

# %%
fig, axes = plt.subplots(figsize=(12, 6), ncols=2, nrows=1)

axes[0].plot(history.history['loss'], label='loss')
axes[0].plot(history.history['val_loss'], label='val_loss')
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].legend()
axes[1].plot(history.history['CER_metric'], label='CER_metric')
axes[1].plot(history.history['val_CER_metric'], label='val_CER_metric')
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Character Error Rate")
axes[1].legend()

plt.show()

# %%
model.save('./crnn.h5')

# %%
# model = load_model('path/to/model', custom_objects={'CTCLoss' : CTCLoss, 'CERMetric': CERMetric})

# %% [markdown]
# ## Model training results

# %%
# Test results: (loss, cer)

model.evaluate(test_X, test_y)
# Out:
# 62/62 [==============================] - 10s 138ms/step - loss: 26.3437 - CER_metric: 0.0910
# [26.343658447265625, 0.09098370373249054]

# %%
# Decode label for single image

def num_to_label(num, alphabet):
    text = ""
    for ch in num:
        if ch == len(alphabet): # ctc blank
          break
        else:
          text += alphabet[ch]
    return text


# Decode labels for softmax matrix

def decode_text(nums):
  values = get_value(
      ctc_decode(nums, input_length=np.ones(nums.shape[0])*nums.shape[1], 
                 greedy=True)[0][0])

  texts = []
  for i in range(nums.shape[0]):
    value = values[i]
    texts.append(num_to_label(value[value >= 0], alphabet))
  return texts

# %%
predicts = model.predict(test_X)
predicts = decode_text(predicts)
# Out:
# 62/62 [==============================] - 6s 82ms/step

# %%
# Prediction results

fig, axes = plt.subplots(figsize=(30, 60), ncols=2, nrows=32)

test_X = test_X.astype('int')

# Title format: GT - Predict
for i in range(64):
  axes[i // 2, i % 2].imshow(cv2.rotate(
      (test_X[i]).astype(np.uint8),cv2.ROTATE_90_COUNTERCLOCKWISE),
      cmap='gray')
  axes[i // 2, i % 2].set_title(
      f'{num_to_label(test_y[i], alphabet)} - {predicts[i]}')
  axes[i // 2, i % 2].axis("off")
