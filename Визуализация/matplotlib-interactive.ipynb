# %%
# %matplotlib notebook

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation
import os

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Пример 1

# %%
xs = np.linspace(-10,10,100)
ys = np.sin(xs)
model = LinearRegression()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10,5)

l1, = ax.plot([],[], 'bo')
l2, = ax.plot([],[], 'r')

left_l, = ax.plot([],[], c='g')
left_r, = ax.plot([],[], c='g')

K = ax.text(0,0,"", size=20)

def animate(i):
    left, right = i*0.1, 2*np.pi+i*0.1
    
    xs_a = np.linspace(left, right, 100)
    ys_a = np.sin(10*xs_a) + 3*np.sin(xs_a/3) + np.random.random(len(xs_a))*0.1
        
    l1.set_data(xs_a, ys_a)   
    model.fit(xs_a.reshape(-1,1), ys_a)
    l2.set_data([xs_a[0],xs_a[-1]], [*model.predict([[xs_a[0]]]), *model.predict([[xs_a[-1]]])])
            
    left_l.set_data([left+(right-left)*0.2, left+(right-left)*0.2],[-8, 8])
    left_r.set_data([left+(right-left)*0.8, left+(right-left)*0.8],[-8, 8])
    
    
    K.set_x(left+3)
    K.set_y(6)
    K.set_text("K={}".format(round(model.coef_[0],2)))
    if abs(model.coef_[0])>0.5:
        K.set_color('r')
    elif abs(model.coef_[0])>0.3:
        K.set_color('y')
    else:
        K.set_color('g')

    ax.axis([left, right, -8, 8])


fps = 10

ani = animation.FuncAnimation(fig, animate, frames=500, interval=1000./fps)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
ani.save('myAnimation.gif', writer='pillow', fps=10)

# %% [markdown]
# <img src='./myAnimation.gif'>

# %%
if os.path.exists('./myAnimation.gif'):
    os.remove('./myAnimation.gif')

# %% [markdown]
# #### Пример 2

# %%
np.random.seed(42)
xs = np.linspace(-10, 10, 100)
ys1 = np.sin(xs) - 1
ys2 = np.sin(xs) + 1 
ys3 = np.sin(xs) + (np.random.random(100)-0.5)*2

plt.plot(xs, ys1, c='r')
plt.plot(xs, ys2, c='r')
plt.scatter(xs, ys3, c='b')
plt.plot(xs, ys3, c='b')
plt.fill_between(xs, ys1, ys2, color='green', alpha=0.3)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10,5)

l1, = ax.plot([],[], 'bo')
l2, = ax.plot([],[], 'r')

left_l, = ax.plot([],[], c='g')
left_r, = ax.plot([],[], c='g')

K = ax.text(0,0,"", size=20)

def animate(i):
    left, right = i*0.1, 2*np.pi+i*0.1
    
    xs_a = np.linspace(left, right, 100)
    ys_a = np.sin(10*xs_a) + 3*np.sin(xs_a/3) + np.random.random(len(xs_a))*0.1
        
    l1.set_data(xs_a, ys_a)   
    model.fit(xs_a.reshape(-1,1), ys_a)
    l2.set_data([xs_a[0],xs_a[-1]], [*model.predict([[xs_a[0]]]), *model.predict([[xs_a[-1]]])])
            
    left_l.set_data([left+(right-left)*0.2, left+(right-left)*0.2],[-8, 8])
    left_r.set_data([left+(right-left)*0.8, left+(right-left)*0.8],[-8, 8])
    
    
    K.set_x(left+3)
    K.set_y(6)
    K.set_text("K={}".format(round(model.coef_[0],2)))
    if abs(model.coef_[0])>0.5:
        K.set_color('r')
    elif abs(model.coef_[0])>0.3:
        K.set_color('y')
    else:
        K.set_color('g')

    ax.axis([left, right, -8, 8])


fps = 10

ani = animation.FuncAnimation(fig, animate, frames=500, interval=1000./fps)
